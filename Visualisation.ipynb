# %% [markdown]
# <a href="https://colab.research.google.com/github/Petegichana/Machine-Learning-Algorithms/blob/main/Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#read dataset
import pandas as pd 
students=pd.read_csv("https://modcom.co.ke/data/datasets/schoolcleaned.csv")  
students.head()
# Out:
#    Unnamed: 0    ids        bday  enrolldate  expgradate      Rank  \
# 0           0  43783  1995-03-22  2014-08-04  2019-05-13   Unknown
# 1          29  20230  1996-01-02  2014-08-04  2020-05-11  Freshmen
# 2          30  21083  1995-12-22  2014-08-04  2020-05-11  Freshmen
# 3          31  21939  1995-12-12  2014-08-04  2020-05-11  Freshmen
# 4          32  23017  1995-11-29  2014-08-04  2020-05-11  Freshmen
#
#         Major   Gender      Athlete  Height  ...   Math    Writing     State  \
# 0      uknown     Male  Non-Athlete  217.05  ...  60.02  81.440000  In state
# 1  pre-pharma     Male      Athlete  240.33  ...  65.36  76.070000  In state
# 2      uknown   Female  Non-Athlete  216.15  ...  68.53  71.420000  In state
# 3      uknown     Male      Athlete  198.27  ...  61.61  79.521683  In state
# 4      uknown  Unknown  Non-Athlete  215.16  ...  65.25  72.610000  In state
#
#    LiveOnCampus  HowCommute  CommuteTime  SleepTime StudyTime Performance  \
# ...

# %%
#visualisation libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use("seaborn")

# %%
#piechart
students.groupby('Gender').size().plot(kind='pie', autopct = '%2.1f%%')
plt.title('Distribution of Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Gender')

# %%
students.groupby(['HowCommute', 'State']).size().plot(kind='pie',autopct='%2.1f%%') 
plt.title('Distribution of how students commute by state')
# Out:
# Text(0.5, 1.0, 'Distribution of how students commute by state')

# %%
#show the mean of math for students based on their gender and state then visualise the results on a bar graph
students.groupby(['Gender', 'State'])['Math'].mean().plot(kind='bar')

# %%
#count plot -> depict the number of count on a categorical data
ax = sns.countplot(students['State'])
for p in ax.patches:
  txt =str(p.get_height().round(1))+''
  txt_x = p.get_x()
  txt_y = p.get_height()
  ax.text(txt_x, txt_y, txt)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#distribtion of contionous variable
sns.distplot(students['Height'], kde = False)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#scatter plot
#shows two continous values and how they are related

sns.scatterplot(x='Weight',y='Height', data=students)

# %%
#heatmap-> depicts relationship bettween continous variable
subset = students[['Weight', 'Height','Reading', 'Writing','Sprint']]
sns.heatmap(subset.corr(), annot=True, cmap='Greens')

# %%
#botplot ->generates the outliers (unusual data plots)
sns.boxplot(y='Math', x='Rank', data = students)
#percentiles
#upper percentile Q3
#lower percentile(25%) Q1
#IQR= Q3-Q1
#outliers_upper = Q3 + IQR *1.5
#outliers_lower = Q1 + IQR *1.5

# %%
#Concentration of the data point
#violin plot
sns.violinplot(x='Gender',y='Reading', data= students)

# %%
#swarmplot
sns.swarmplot(x='Gender',y='Reading', data= students)
